# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
path="https://raw.githubusercontent.com/18cse098/dmdw/main/bestsellers%20with%20categories.csv"

# %%
import pandas as pd
data=pd.read_csv(path)

# %%
data.head()
# Out:
#                                                 Name  ...        Genre
# 0                      10-Day Green Smoothie Cleanse  ...  Non Fiction
# 1                                  11/22/63: A Novel  ...      Fiction
# 2            12 Rules for Life: An Antidote to Chaos  ...  Non Fiction
# 3                             1984 (Signet Classics)  ...      Fiction
# 4  5,000 Awesome Facts (About Everything!) (Natio...  ...  Non Fiction
#
# [5 rows x 7 columns]

# %%
data
# Out:
#                                                   Name  ...        Genre
# 0                        10-Day Green Smoothie Cleanse  ...  Non Fiction
# 1                                    11/22/63: A Novel  ...      Fiction
# 2              12 Rules for Life: An Antidote to Chaos  ...  Non Fiction
# 3                               1984 (Signet Classics)  ...      Fiction
# 4    5,000 Awesome Facts (About Everything!) (Natio...  ...  Non Fiction
# ..                                                 ...  ...          ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)  ...      Fiction
# 546  You Are a Badass: How to Stop Doubting Your Gr...  ...  Non Fiction
# 547  You Are a Badass: How to Stop Doubting Your Gr...  ...  Non Fiction
# 548  You Are a Badass: How to Stop Doubting Your Gr...  ...  Non Fiction
# 549  You Are a Badass: How to Stop Doubting Your Gr...  ...  Non Fiction
#
# [550 rows x 7 columns]

# %%
data.tail()
# Out:
#                                                   Name  ...        Genre
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)  ...      Fiction
# 546  You Are a Badass: How to Stop Doubting Your Gr...  ...  Non Fiction
# 547  You Are a Badass: How to Stop Doubting Your Gr...  ...  Non Fiction
# 548  You Are a Badass: How to Stop Doubting Your Gr...  ...  Non Fiction
# 549  You Are a Badass: How to Stop Doubting Your Gr...  ...  Non Fiction
#
# [5 rows x 7 columns]

# %%
data.dropna(axis=0,inplace=True)

# %%
data.shape
# Out:
# (550, 7)

# %%
data.head()
# Out:
#                                                 Name  ...        Genre
# 0                      10-Day Green Smoothie Cleanse  ...  Non Fiction
# 1                                  11/22/63: A Novel  ...      Fiction
# 2            12 Rules for Life: An Antidote to Chaos  ...  Non Fiction
# 3                             1984 (Signet Classics)  ...      Fiction
# 4  5,000 Awesome Facts (About Everything!) (Natio...  ...  Non Fiction
#
# [5 rows x 7 columns]

# %%
plt.scatter(data['User Rating'],data['Price'],c='green')
plt.xlabel('User Rating')
plt.ylabel('price')
plt.show()

# %%
plt.hist(data['Reviews'])
# Out:
# (array([287., 131.,  87.,  25.,   4.,   8.,   5.,   0.,   0.,   3.]),
#  array([3.70000e+01, 8.81740e+03, 1.75978e+04, 2.63782e+04, 3.51586e+04,
#         4.39390e+04, 5.27194e+04, 6.14998e+04, 7.02802e+04, 7.90606e+04,
#         8.78410e+04]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data['Reviews'],color='green',edgecolor='white',bins=5)
plt.title("historgram of Reviews")
plt.xlabel(" ")
plt.ylabel(" ")
plt.show()

# %%
import seaborn as sns

# %%
sns.set(style='darkgrid')
sns.regplot(x=data['User Rating'],y=data['Price'])

# %%
sns.set(style='darkgrid')
sns.regplot(x=data['User Rating'],y=data['Price'],marker='*',fit_reg=False)

# %%
sns.distplot(data['User Rating'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(data['User Rating'],kde=False)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(data['User Rating'],kde=False,bins=5)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.countplot(x="Genre",data=data)

# %%
sns.countplot(x="Genre",data=data,hue='Year')

# %%
sns.boxplot(y=data['Price'])
